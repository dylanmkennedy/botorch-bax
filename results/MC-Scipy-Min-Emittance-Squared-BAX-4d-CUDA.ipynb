# %% [markdown]
# # To-Do:
#
# - InputStandardize vs Normalize
#
# - check hyperparam/prior definitions (scaled space vs raw space)
#
# - keep in mind modality of NaN results in emittance
#
# - Try different number of steps along measurement dimension
#
# - inrease dimensionality of tuning space
#
# - fix legend location (only plot on 1 heatmap)

# %% [markdown]
# # In this notebook, we fit a gpytorch GP to a simple emittance model with 1 tuning parameter. We use the GP to evaluate the Expected Information Gain toward the result of a grid-scan minimization routine.

# %%
import torch
from emitutils import toy_beam_size_squared_nd, fit_gp_model_emittance
from utils import unif_random_sample_domain
from matplotlib import pyplot as plt
from algorithms import ScipyMinimizeEmittance
from acquisition import ExpectedInformationGain
from botorch.optim import optimize_acqf
import time
from mpl_toolkits.axes_grid1 import make_axes_locatable
import copy

# %% [markdown]
# # Suppress warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CUDA option

# %%
use_gpu = False
if use_gpu:
    if torch.cuda.is_available():
        print('CUDA is available. Using default GPU.')
        torch.set_default_tensor_type('torch.cuda.DoubleTensor')
    else:
        print('CUDA not available. Using CPU.')
        use_gpu = False  
else:
    print('Using CPU.')
# Out:
# Using CPU.

# %% [markdown]
# # Monte Carlo Settings

# %%
# domain = torch.tensor([[-2,2], [-65,35]]).double() #the acquisition domain, must have shape = (ndim, 2)
domain = torch.tensor([[-3,1], [-40,60]]).double() #the acquisition domain, must have shape = (ndim, 2)
ndim = domain.shape[0]                               #where domain[i,0] and domain[i,1] represent
                                                        #the lower and upper bounds of the ith input dimension
                                                        #(these same bounds will be applied to the sampled execution paths) 

    

    
n_samples = 10 #number of posterior samples on which to evaluate execution paths
n_steps_measurement_param = 3





random_acq = False
n_trials = 10
n_iter = 50
n_obs_init = 5 #number of random observations on which to initialize model

# %% [markdown]
# # Run trials

# %%
trial_data = {}
trial_data['settings'] = {'domain':domain,
                         'ndim':ndim,
                         'n_obs_init': n_obs_init,
                         'n_samples':n_samples,
                         'n_steps_measurement_param': n_steps_measurement_param,
                         'n_trials':n_trials,
                         'n_iter':n_iter,
                         'random_acq':random_acq}

times = []

for trial in range(n_trials):
    torch.manual_seed(trial)

    #build ndim dimensional parabolic target function
    target_func = toy_beam_size_squared_nd


    ##########################################
    #Observe target function n_obs_init times using a uniform sample of the domain
    x_obs = unif_random_sample_domain(n_samples = n_obs_init, domain = domain)

    y_obs = target_func(x_obs)




    #fit model on initial observations
    model = fit_gp_model_emittance(x_obs, y_obs*1.e6)

    
    algo = ScipyMinimizeEmittance(domain = domain, 
                   n_samples = n_samples)
    
    rng_state = torch.get_rng_state()
    
    acq_fn = ExpectedInformationGain(model = model, algo = algo)
        
    if random_acq:
        x_next = None
    else:
        x_next, _ = optimize_acqf(
            acq_function=acq_fn,
            bounds=acq_fn.algo.domain.T,
            q=1,
            num_restarts=10,
            raw_samples=100,
            options={},
            )

    
    iter_data = {}
    iter_data[0] = {'x_obs': x_obs,
                   'y_obs': y_obs,
                    'x_next': x_next,
                   'model':  copy.deepcopy(model),
                   'rng_state': rng_state}
    
    
    for i in range(1, n_iter+1):
        start = time.time()
        print('Iteration', trial*n_iter + i, '/', n_trials*n_iter)
        
        if random_acq:
            x_new = unif_random_sample_domain(n_samples = 1, domain = domain)
        else:
            x_new = x_next
            
        y_new = target_func(x_new)

        x_obs = torch.cat((x_obs, x_new), dim=0)
        y_obs = torch.cat((y_obs, y_new), dim=0)

        model = fit_gp_model_emittance(x_obs, y_obs*1.e6)

        rng_state = torch.get_rng_state()
        
        acq_fn = ExpectedInformationGain(model = model, algo = algo)

        
        if random_acq:
            x_next = None
        else:
            x_next, _ = optimize_acqf(
                acq_function=acq_fn,
                bounds=acq_fn.algo.domain.T,
                q=1,
                num_restarts=20,
                raw_samples=100,
                options={},
                )
            
        end = time.time()
        
        this_time = end - start
        
        print('Operation took', this_time, 'seconds.')
        
        times += [this_time]
        
        total_time = sum(times)
        print('Total time elapsed:', total_time, 'seconds.')
        
        total_iters = (trial*n_iter + i)
        avg_time = total_time/total_iters
        print('Estimated time remaining:', avg_time*(n_trials*n_iter - total_iters), 'seconds.')
        
        print('\n')
        
        iter_data[i] = {'x_obs': x_obs,
                   'y_obs': y_obs,
                    'x_next': x_next,
                   'model':  copy.deepcopy(model),
                   'rng_state': rng_state}
        
    trial_data[trial] = iter_data
# Out:
# Iteration 1 / 500
# Operation took 1.7141668796539307 seconds.
# Total time elapsed: 1.7141668796539307 seconds.
# Estimated time remaining: 855.3692729473114 seconds.
#
#
# Iteration 2 / 500
# Operation took 2.0355868339538574 seconds.
# Total time elapsed: 3.749753713607788 seconds.
# Estimated time remaining: 933.6886746883392 seconds.
#
#
# Iteration 3 / 500
# Operation took 1.9309008121490479 seconds.
# Total time elapsed: 5.680654525756836 seconds.
# Estimated time remaining: 941.0950997670492 seconds.
#
#
# Iteration 4 / 500
# Operation took 2.5344700813293457 seconds.
# Total time elapsed: 8.215124607086182 seconds.
# Estimated time remaining: 1018.6754512786865 seconds.
#
#
# Iteration 5 / 500
# Operation took 1.281804084777832 seconds.
# Total time elapsed: 9.496928691864014 seconds.
# Estimated time remaining: 940.1959404945374 seconds.
#
#
# Iteration 6 / 500
# Operation took 1.9159643650054932 seconds.
# Total time elapsed: 11.412893056869507 seconds.
# Estimated time remaining: 939.6615283489227 seconds.
#
#
# Iteration 7 / 500
# Operation took 1.3007264137268066 seconds.
# Total time elapsed: 12.713619470596313 seconds.
# Estimated time remaining: 895.4020570005689 seconds.
#
#
# Iteration 8 / 500
# Operation took 1.2189526557922363 seconds.
# Total time elapsed: 13.93257212638855 seconds.
# Estimated time remaining: 856.8531857728958 seconds.
#
#
# Iteration 9 / 500
# Operation took 1.8071882724761963 seconds.
# Total time elapsed: 15.739760398864746 seconds.
# Estimated time remaining: 858.6913728713989 seconds.
#
#
# Iteration 10 / 500
# Operation took 4.339298725128174 seconds.
# Total time elapsed: 20.07905912399292 seconds.
# Estimated time remaining: 983.8738970756532 seconds.
#
#
# Iteration 11 / 500
# Operation took 1.3407349586486816 seconds.
# Total time elapsed: 21.4197940826416 seconds.
# Estimated time remaining: 952.2072096737948 seconds.
#
#
# Iteration 12 / 500
# Operation took 2.212916851043701 seconds.
# Total time elapsed: 23.632710933685303 seconds.
# Estimated time remaining: 961.063577969869 seconds.
#
#
# Iteration 13 / 500
# Operation took 0.8759815692901611 seconds.
# Total time elapsed: 24.508692502975464 seconds.
# Estimated time remaining: 918.1333268422347 seconds.
#
#
# Iteration 14 / 500
# Operation took 1.129227638244629 seconds.
# Total time elapsed: 25.637920141220093 seconds.
# Estimated time remaining: 890.0020849023547 seconds.
#
#
# Iteration 15 / 500
# Operation took 1.2262141704559326 seconds.
# Total time elapsed: 26.864134311676025 seconds.
# Estimated time remaining: 868.6070094108582 seconds.
#
#
# Iteration 16 / 500
# Operation took 1.4585261344909668 seconds.
# Total time elapsed: 28.322660446166992 seconds.
# Estimated time remaining: 856.7604784965515 seconds.
#
#
# Iteration 17 / 500
# Operation took 1.468461036682129 seconds.
# Total time elapsed: 29.79112148284912 seconds.
# Estimated time remaining: 846.4183338950662 seconds.
#
#
# Iteration 18 / 500
# Operation took 1.9587254524230957 seconds.
# Total time elapsed: 31.749846935272217 seconds.
# Estimated time remaining: 850.1903457111783 seconds.
#
#
# Iteration 19 / 500
# Operation took 1.8849825859069824 seconds.
# Total time elapsed: 33.6348295211792 seconds.
# Estimated time remaining: 851.4922631414313 seconds.
#
#
# Iteration 20 / 500
# Operation took 1.5089545249938965 seconds.
# Total time elapsed: 35.143784046173096 seconds.
# Estimated time remaining: 843.4508171081543 seconds.
#
#
# Iteration 21 / 500
# Operation took 1.508814811706543 seconds.
# Total time elapsed: 36.65259885787964 seconds.
# Estimated time remaining: 836.0283263297308 seconds.
#
#
# Iteration 22 / 500
# Operation took 4.1830735206604 seconds.
# Total time elapsed: 40.83567237854004 seconds.
# Estimated time remaining: 887.2477907700971 seconds.
#
#
# Iteration 23 / 500
# Operation took 2.363246202468872 seconds.
# Total time elapsed: 43.19891858100891 seconds.
# Estimated time remaining: 895.9080070930979 seconds.
#
#
# Iteration 24 / 500
# Operation took 1.4370968341827393 seconds.
# Total time elapsed: 44.63601541519165 seconds.
# Estimated time remaining: 885.280972401301 seconds.
#
#
# Iteration 25 / 500
# Operation took 1.9329326152801514 seconds.
# Total time elapsed: 46.5689480304718 seconds.
# Estimated time remaining: 884.8100125789642 seconds.
#
#
# Iteration 26 / 500
# Operation took 2.2382023334503174 seconds.
# Total time elapsed: 48.80715036392212 seconds.
# Estimated time remaining: 889.7918950961187 seconds.
#
#
# Iteration 27 / 500
# Operation took 0.9597296714782715 seconds.
# Total time elapsed: 49.76688003540039 seconds.
# Estimated time remaining: 871.8420095090512 seconds.
#
#
# Iteration 28 / 500
# Operation took 1.3560197353363037 seconds.
# Total time elapsed: 51.122899770736694 seconds.
# Estimated time remaining: 861.7860247067043 seconds.
#
#
# Iteration 29 / 500
# Operation took 2.072019100189209 seconds.
# Total time elapsed: 53.1949188709259 seconds.
# Estimated time remaining: 863.9588547657277 seconds.
#
#
# Iteration 30 / 500
# Operation took 1.7111995220184326 seconds.
# Total time elapsed: 54.906118392944336 seconds.
# Estimated time remaining: 860.1958548227946 seconds.
#
#
# Iteration 31 / 500
# Operation took 1.0728402137756348 seconds.
# Total time elapsed: 55.97895860671997 seconds.
# Estimated time remaining: 846.9074705339247 seconds.
#
#
# Iteration 32 / 500
# Operation took 1.5013997554779053 seconds.
# Total time elapsed: 57.480358362197876 seconds.
# Estimated time remaining: 840.6502410471439 seconds.
#
#
# Iteration 33 / 500
# Operation took 6.028474807739258 seconds.
# Total time elapsed: 63.508833169937134 seconds.
# Estimated time remaining: 898.7462148594134 seconds.
#
#
# Iteration 34 / 500
# Operation took 1.4675002098083496 seconds.
# Total time elapsed: 64.97633337974548 seconds.
# Estimated time remaining: 890.5579810282763 seconds.
#
#
# Iteration 35 / 500
# Operation took 2.1050844192504883 seconds.
# Total time elapsed: 67.08141779899597 seconds.
# Estimated time remaining: 891.2245507580893 seconds.
#
#
# Iteration 36 / 500
# Operation took 3.9609334468841553 seconds.
# Total time elapsed: 71.04235124588013 seconds.
# Estimated time remaining: 915.656971613566 seconds.
#
#
# Iteration 37 / 500
# Operation took 2.2645559310913086 seconds.
# Total time elapsed: 73.30690717697144 seconds.
# Estimated time remaining: 917.3269735929129 seconds.
#
#
# Iteration 38 / 500
# Operation took 1.8610002994537354 seconds.
# Total time elapsed: 75.16790747642517 seconds.
# Estimated time remaining: 913.8835066870639 seconds.
#
#
# Iteration 39 / 500
# Operation took 7.356475830078125 seconds.
# Total time elapsed: 82.5243833065033 seconds.
# Estimated time remaining: 975.4805308794365 seconds.
#
#
# Iteration 40 / 500
# Operation took 7.004526853561401 seconds.
# Total time elapsed: 89.5289101600647 seconds.
# Estimated time remaining: 1029.582466840744 seconds.
#
#
# Iteration 41 / 500
# Operation took 1.731588363647461 seconds.
# Total time elapsed: 91.26049852371216 seconds.
# Estimated time remaining: 1021.6724103020458 seconds.
#
#
# Iteration 42 / 500
# Operation took 3.191427707672119 seconds.
# Total time elapsed: 94.45192623138428 seconds.
# Estimated time remaining: 1029.975766999381 seconds.
#
#
# Iteration 43 / 500
# Operation took 1.1950559616088867 seconds.
# Total time elapsed: 95.64698219299316 seconds.
# Estimated time remaining: 1016.527229353439 seconds.
#
#
# Iteration 44 / 500
# Operation took 1.6350598335266113 seconds.
# Total time elapsed: 97.28204202651978 seconds.
# Estimated time remaining: 1008.1957082748413 seconds.
#
#
# Iteration 45 / 500
# Operation took 1.4929585456848145 seconds.
# Total time elapsed: 98.77500057220459 seconds.
# Estimated time remaining: 998.7250057856243 seconds.
#
#
# Iteration 46 / 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22256\3419793135.py in <cell line: 13>()
#      77         rng_state = torch.get_rng_state()
#      78
# ---> 79         acq_fn = ExpectedInformationGain(model = model, algo = algo)
#      80
#      81
#
# ~\SLAC\botorch-bax\acquisition.py in __init__(self, model, algo)
#      32         super().__init__(model=model)
#      33         self.algo = algo
# ---> 34         self.xs_exe, self.ys_exe = self.algo.get_exe_paths(self.model) #get sampled execution paths and set self.xs_exe, self.ys_exe
#      35
#      36         self.model(self.xs_exe) #call model on some data to avoid errors. we don't need this result.
#
# ~\SLAC\botorch-bax\algorithms.py in get_exe_paths(self, model)
#     293         target_func_for_scipy = sum_samplewise_emittance_flat_X_wrapper_for_scipy(self.post_paths, self.n_samples, self.X_meas)
#     294
# --> 295         res = minimize(target_func_for_scipy, X_tuning_init.detach().cpu().numpy(),
#     296                        bounds = self.domain[:-1].repeat(self.n_samples,1).detach().cpu().numpy(),
#     297                        tol=1e-3, options = {'eps': 1e-03})
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     697                                  **options)
#     698     elif meth == 'l-bfgs-b':
# --> 699         res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     700                                callback=callback, **options)
#     701     elif meth == 'tnc':
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     284             self._update_x_impl(x)
#     285         self._update_fun()
# --> 286         self._update_grad()
#     287         return self.f, self.g
#     288
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_grad(self)
#     254     def _update_grad(self):
#     255         if not self.g_updated:
# --> 256             self._update_grad_impl()
#     257             self.g_updated = True
#     258
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_grad()
#     171                 self._update_fun()
#     172                 self.ngev += 1
# --> 173                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                                            **finite_diff_options)
#     175
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     503
#     504         if sparsity is None:
# --> 505             return _dense_difference(fun_wrapped, x0, f0, h,
#     506                                      use_one_sided, method)
#     507         else:
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574             x = x0 + h_vecs[i]
#     575             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576             df = fun(x) - f0
#     577         elif method == '3-point' and use_one_sided[i]:
#     578             x1 = x0 + h_vecs[i]
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_numdiff.py in fun_wrapped(x)
#     454
#     455     def fun_wrapped(x):
# --> 456         f = np.atleast_1d(fun(x, *args, **kwargs))
#     457         if f.ndim > 1:
#     458             raise RuntimeError("`fun` return value has "
#
# ~\Anaconda3\envs\BOTORCH\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# ~\SLAC\botorch-bax\emitutils.py in wrapped_func(X_tuning_flat)
#     122
#     123     def wrapped_func(X_tuning_flat):
# --> 124         return sum_samplewise_emittance_flat_X(post_paths, n_samples, torch.tensor(X_tuning_flat), X_meas).detach().cpu().numpy()
#     125
#     126     return wrapped_func
#
# ~\SLAC\botorch-bax\emitutils.py in sum_samplewise_emittance_flat_X(post_paths, n_samples, X_tuning_flat, X_meas)
#     143     X_tuning = X_tuning_flat.double().reshape(n_samples,-1)
#     144
# --> 145     return torch.sum(post_emit(post_paths, X_tuning, X_meas, samplewise=True, squared=True))
#     146
#     147 def post_emit_batched_input(post_paths, X_tuning, X_meas, samplewise=False, squared=False):
#
# ~\SLAC\botorch-bax\emitutils.py in post_emit(post_paths, X_tuning, X_meas, samplewise, squared)
#     239     xs = torch.cat((xs_tuning, X_meas_repeated), dim=1)
#     240
# --> 241     ys = post_paths(xs) #ys will be shape nsamples x (n_tuning_configs*n_steps_quad_scan)
#     242 #     print('ys.shape =', ys.shape)
#     243     n_samples = ys.shape[0]
#
# ~\SLAC\botorch-bax\samplingutils.py in post_paths(xs)
#     118         update = update.reshape(n_samples,-1)
#     119
# --> 120         prior = product_kernel_prior_paths(xs)
#     121
#     122         post = prior + update + (model.mean_module(xs).reshape(1,-1)).repeat(n_samples,1)
#
# ~\SLAC\botorch-bax\samplingutils.py in product_kernel_prior_paths(xs)
#      73
#      74     def product_kernel_prior_paths(xs):
# ---> 75         return (matern_prior_paths(xs[:,:-1].float()).reshape(n_samples,-1) * quad_prior_paths(xs[:,-1:].float())).double()
#      76
#      77     return product_kernel_prior_paths
#
# ~\SLAC\botorch-bax\samplingutils.py in paths(xs)
#      17             xs = xs.repeat(n_samples,1,1) #duplicate over batch (sample) dim
#      18
# ---> 19         X = torch.concat([xs * xs, (2 * c).sqrt() * xs, c.expand(*xs.shape)], dim=2)
#      20         W = ws.repeat(1,xs.shape[1],1)     #ws is n_samples x 1 x 3 dim
#      21
#
# KeyboardInterrupt:

# %%
acq_fn.xs_exe

# %%
import dill
with open('MC-Emittance-NonPhys-BAX-4d-Results.pkl', 'wb') as f:
    dill.dump(trial_data, f)
