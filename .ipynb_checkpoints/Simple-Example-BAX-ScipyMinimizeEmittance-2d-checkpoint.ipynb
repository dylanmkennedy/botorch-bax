# %% [markdown]
# # 2-dimensional (single tuning-param) emittance optimization via BAX with algorithm ScipyMinimizeEmittance

# %%
import torch
import gpytorch
import botorch
from botorch.optim import optimize_acqf

from algorithms import ScipyMinimizeEmittance, ScipyMinimizeEmittanceParallel
from acquisition import ExpectedInformationGain

from emitutils import toy_beam_size_squared_nd, toy_emit_nd, fit_gp_model_emittance, post_emit, post_mean_emit
from samplingutils import draw_product_kernel_post_paths
from utils import unif_random_sample_domain
from utils import build_mesh_domain

import time
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import copy
import os

# %% [markdown]
# # Suppress warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # BAX settings

# %%
random_seed = 0

# domain = torch.tensor([[-3,1], [-3,1], [-3,1], [-40,60]]).double() #the acquisition domain, must have shape = (ndim, 2)
domain = torch.tensor([[-3,1], [-40,60]]).double() #the acquisition domain, must have shape = (ndim, 2)
ndim = domain.shape[0]                               #where domain[i,0] and domain[i,1] represent
                                                        #the lower and upper bounds of the ith input dimension
                                                        #(these same bounds will be applied to the sampled execution paths) 

    



n_samples = 16
n_steps_measurement_param = 3





n_iter = 25
n_obs_init = 5 #number of random observations on which to initialize model

# %% [markdown]
# # Run BAX optimization loop

# %%
torch.manual_seed(random_seed)

#build ndim dimensional parabolic target function
target_func = toy_beam_size_squared_nd




# Initialize on uniform random observations
#######################################################################
x_obs = unif_random_sample_domain(n_samples = n_obs_init, domain = domain)

y_obs = target_func(x_obs)




#fit model on initial observations
model = fit_gp_model_emittance(x_obs, y_obs*1.e6)



algo = ScipyMinimizeEmittance(domain = domain, n_samples = n_samples)

rng_state = torch.get_rng_state()


    
acq_fn = ExpectedInformationGain(model = model, algo = algo)


x_next, _ = optimize_acqf(
    acq_function=acq_fn,
    bounds=acq_fn.algo.domain.T,
    q=1,
    num_restarts=5,
    raw_samples=500,
    options={},
    )
    
    
iter_data = {}
iter_data[0] = {'x_obs': x_obs,
               'y_obs': y_obs,
                'x_next': x_next,
               'model':  copy.deepcopy(model),
               'rng_state': rng_state}




# Acquire new observations
####################################################################
times = []

for i in range(1, n_iter+1):
    start = time.time()
    print('Iteration', i, '/', n_iter)

    x_new = x_next

    y_new = target_func(x_new)

    x_obs = torch.cat((x_obs, x_new), dim=0)
    y_obs = torch.cat((y_obs, y_new), dim=0)

    model = fit_gp_model_emittance(x_obs, y_obs*1.e6)

    rng_state = torch.get_rng_state()

    acq_fn = ExpectedInformationGain(model = model, algo = algo)

    mid = time.time()
    
    print('exe_paths took', mid - start, 'seconds.')

    x_next, _ = optimize_acqf(
        acq_function=acq_fn,
        bounds=acq_fn.algo.domain.T,
        q=1,
        num_restarts=5,
        raw_samples=500,
        options={},
        )

    
    end = time.time()
    
    print('acq_fn optimization took', end - mid, 'seconds.')

    this_time = end - start

    print('This iteration took', this_time, 'seconds.')

    times += [this_time]

    total_time = sum(times)

    avg_time = total_time/i
    print('Average time per iteration', avg_time, 'seconds.')
    print('Total time elapsed:', total_time, 'seconds.')
    print('Estimated time remaining:', avg_time*(n_iter - i), 'seconds.')
    print('\n')

    iter_data[i] = {'x_obs': x_obs,
               'y_obs': y_obs,
                'x_next': x_next,
               'model':  copy.deepcopy(model),
               'rng_state': rng_state}
# Out:
# Iteration 1 / 25
# exe_paths took 0.7725226879119873 seconds.
# acq_fn optimization took 0.12637662887573242 seconds.
# This iteration took 0.8988993167877197 seconds.
# Total time elapsed: 0.8988993167877197 seconds.
# Average time per iteration 0.8988993167877197 seconds.
# Estimated time remaining: 21.573583602905273 seconds.
#
#
# Iteration 2 / 25
# exe_paths took 0.5400021076202393 seconds.
# acq_fn optimization took 0.5472028255462646 seconds.
# This iteration took 1.087204933166504 seconds.
# Total time elapsed: 1.9861042499542236 seconds.
# Average time per iteration 0.9930521249771118 seconds.
# Estimated time remaining: 22.840198874473572 seconds.
#
#
# Iteration 3 / 25
# exe_paths took 0.6260919570922852 seconds.
# acq_fn optimization took 0.4049956798553467 seconds.
# This iteration took 1.0310876369476318 seconds.
# Total time elapsed: 3.0171918869018555 seconds.
# Average time per iteration 1.0057306289672852 seconds.
# Estimated time remaining: 22.126073837280273 seconds.
#
#
# Iteration 4 / 25
# exe_paths took 0.967907190322876 seconds.
# acq_fn optimization took 0.6223475933074951 seconds.
# This iteration took 1.590254783630371 seconds.
# Total time elapsed: 4.607446670532227 seconds.
# Average time per iteration 1.1518616676330566 seconds.
# Estimated time remaining: 24.18909502029419 seconds.
#
#
# Iteration 5 / 25
# exe_paths took 0.825615644454956 seconds.
# acq_fn optimization took 0.5581934452056885 seconds.
# This iteration took 1.3838090896606445 seconds.
# Total time elapsed: 5.991255760192871 seconds.
# Average time per iteration 1.1982511520385741 seconds.
# Estimated time remaining: 23.965023040771484 seconds.
#
#
# Iteration 6 / 25
# exe_paths took 0.7920854091644287 seconds.
# acq_fn optimization took 0.7292718887329102 seconds.
# This iteration took 1.5213572978973389 seconds.
# Total time elapsed: 7.51261305809021 seconds.
# Average time per iteration 1.2521021763483684 seconds.
# Estimated time remaining: 23.789941350619 seconds.
#
#
# Iteration 7 / 25
# exe_paths took 1.1380627155303955 seconds.
# acq_fn optimization took 0.6377472877502441 seconds.
# This iteration took 1.7758100032806396 seconds.
# Total time elapsed: 9.28842306137085 seconds.
# Average time per iteration 1.3269175801958357 seconds.
# Estimated time remaining: 23.884516443525044 seconds.
#
#
# Iteration 8 / 25
# exe_paths took 0.7707252502441406 seconds.
# acq_fn optimization took 0.9363315105438232 seconds.
# This iteration took 1.7070567607879639 seconds.
# Total time elapsed: 10.995479822158813 seconds.
# Average time per iteration 1.3744349777698517 seconds.
# Estimated time remaining: 23.36539462208748 seconds.
#
#
# Iteration 9 / 25
# exe_paths took 0.7894561290740967 seconds.
# acq_fn optimization took 0.5851032733917236 seconds.
# This iteration took 1.3745594024658203 seconds.
# Total time elapsed: 12.370039224624634 seconds.
# Average time per iteration 1.3744488027360704 seconds.
# Estimated time remaining: 21.991180843777126 seconds.
#
#
# Iteration 10 / 25
# exe_paths took 1.037001609802246 seconds.
# acq_fn optimization took 0.6055960655212402 seconds.
# This iteration took 1.6425976753234863 seconds.
# Total time elapsed: 14.01263689994812 seconds.
# Average time per iteration 1.401263689994812 seconds.
# Estimated time remaining: 21.01895534992218 seconds.
#
#
# Iteration 11 / 25
# exe_paths took 0.6828463077545166 seconds.
# acq_fn optimization took 0.5253331661224365 seconds.
# This iteration took 1.2081794738769531 seconds.
# Total time elapsed: 15.220816373825073 seconds.
# Average time per iteration 1.383710579438643 seconds.
# Estimated time remaining: 19.371948112141002 seconds.
#
#
# Iteration 12 / 25
# exe_paths took 0.6850974559783936 seconds.
# acq_fn optimization took 4.0886924266815186 seconds.
# This iteration took 4.773789882659912 seconds.
# Total time elapsed: 19.994606256484985 seconds.
# Average time per iteration 1.6662171880404155 seconds.
# Estimated time remaining: 21.660823444525402 seconds.
#
#
# Iteration 13 / 25
# exe_paths took 0.8629786968231201 seconds.
# acq_fn optimization took 1.4396138191223145 seconds.
# This iteration took 2.3025925159454346 seconds.
# Total time elapsed: 22.29719877243042 seconds.
# Average time per iteration 1.7151691363408015 seconds.
# Estimated time remaining: 20.58202963608962 seconds.
#
#
# Iteration 14 / 25
# exe_paths took 1.1679801940917969 seconds.
# acq_fn optimization took 0.7905347347259521 seconds.
# This iteration took 1.958514928817749 seconds.
# Total time elapsed: 24.25571370124817 seconds.
# Average time per iteration 1.7325509786605835 seconds.
# Estimated time remaining: 19.05806076526642 seconds.
#
#
# Iteration 15 / 25
# exe_paths took 1.2922565937042236 seconds.
# acq_fn optimization took 0.98844313621521 seconds.
# This iteration took 2.2806997299194336 seconds.
# Total time elapsed: 26.536413431167603 seconds.
# Average time per iteration 1.7690942287445068 seconds.
# Estimated time remaining: 17.69094228744507 seconds.
#
#
# Iteration 16 / 25
# exe_paths took 1.2413930892944336 seconds.
# acq_fn optimization took 0.804969310760498 seconds.
# This iteration took 2.0463624000549316 seconds.
# Total time elapsed: 28.582775831222534 seconds.
# Average time per iteration 1.7864234894514084 seconds.
# Estimated time remaining: 16.077811405062675 seconds.
#
#
# Iteration 17 / 25
# exe_paths took 0.9919755458831787 seconds.
# acq_fn optimization took 0.7201049327850342 seconds.
# This iteration took 1.712080478668213 seconds.
# Total time elapsed: 30.294856309890747 seconds.
# Average time per iteration 1.782050371170044 seconds.
# Estimated time remaining: 14.256402969360352 seconds.
#
#
# Iteration 18 / 25
# exe_paths took 0.588111400604248 seconds.
# acq_fn optimization took 1.097639799118042 seconds.
# This iteration took 1.68575119972229 seconds.
# Total time elapsed: 31.980607509613037 seconds.
# Average time per iteration 1.7767004172007244 seconds.
# Estimated time remaining: 12.436902920405071 seconds.
#
#
# Iteration 19 / 25
# exe_paths took 2.212017774581909 seconds.
# acq_fn optimization took 1.1578171253204346 seconds.
# This iteration took 3.3698348999023438 seconds.
# Total time elapsed: 35.35044240951538 seconds.
# Average time per iteration 1.8605496005008095 seconds.
# Estimated time remaining: 11.163297603004857 seconds.
#
#
# Iteration 20 / 25
# exe_paths took 1.3377776145935059 seconds.
# acq_fn optimization took 0.9053456783294678 seconds.
# This iteration took 2.2431232929229736 seconds.
# Total time elapsed: 37.593565702438354 seconds.
# Average time per iteration 1.8796782851219178 seconds.
# Estimated time remaining: 9.398391425609589 seconds.
#
#
# Iteration 21 / 25
# exe_paths took 1.0539343357086182 seconds.
# acq_fn optimization took 0.622035026550293 seconds.
# This iteration took 1.6759693622589111 seconds.
# Total time elapsed: 39.269535064697266 seconds.
# Average time per iteration 1.8699778602236794 seconds.
# Estimated time remaining: 7.479911440894718 seconds.
#
#
# Iteration 22 / 25
# exe_paths took 0.9388527870178223 seconds.
# acq_fn optimization took 0.5671894550323486 seconds.
# This iteration took 1.506042242050171 seconds.
# Total time elapsed: 40.77557730674744 seconds.
# Average time per iteration 1.8534353321248835 seconds.
# Estimated time remaining: 5.560305996374651 seconds.
#
#
# Iteration 23 / 25
# exe_paths took 0.911670446395874 seconds.
# acq_fn optimization took 1.085555076599121 seconds.
# This iteration took 1.9972255229949951 seconds.
# Total time elapsed: 42.77280282974243 seconds.
# Average time per iteration 1.8596870795540188 seconds.
# Estimated time remaining: 3.7193741591080376 seconds.
#
#
# Iteration 24 / 25
# exe_paths took 0.7704248428344727 seconds.
# acq_fn optimization took 1.8655335903167725 seconds.
# This iteration took 2.635958433151245 seconds.
# Total time elapsed: 45.40876126289368 seconds.
# Average time per iteration 1.8920317192872365 seconds.
# Estimated time remaining: 1.8920317192872365 seconds.
#
#
# Iteration 25 / 25
# exe_paths took 0.6749072074890137 seconds.
# acq_fn optimization took 0.7118749618530273 seconds.
# This iteration took 1.386782169342041 seconds.
# Total time elapsed: 46.79554343223572 seconds.
# Average time per iteration 1.8718217372894288 seconds.
# Estimated time remaining: 0.0 seconds.

# %% [markdown]
# # Results plotting:

# %%
#Select iteration:
i = n_iter #defaults to the last iteration



#extract model
model_i = iter_data[i]['model']

#get BAX predicted algorithm output (X_tuning_star, emit_star) from model posterior mean
X_tuning_star_i, emit_star_i = algo.mean_output(model_i, num_restarts=8)


#set rng state immediately before reconstructing acquisition function (as that is when the state was saved)
rng_state_i = iter_data[i]['rng_state']
torch.set_rng_state(rng_state_i)

#reconstruct acquisition function
acq_fn_i = ExpectedInformationGain(model = model_i, algo = algo)

#get observations
x_obs_i = iter_data[i]['x_obs']

# Get the locations in tuning parameter space (1-dim) of the optimized sample emittances
x_stars = acq_fn_i.xs_exe[:,0,:-1]

# %% [markdown]
# # Plot posterior mean beamsize results heatmap (2d)

# %%
fig, ax = plt.subplots(1)

nsteps_mesh = 100
xs_mesh_n_by_d, x_mesh_tuple = build_mesh_domain(nsteps_mesh, domain)
x0mesh, x1mesh = x_mesh_tuple
p = acq_fn_i.model.posterior(xs_mesh_n_by_d)
ys_mesh = p.mean.reshape(nsteps_mesh,nsteps_mesh)
ax.pcolor(x0mesh.detach().numpy(), x1mesh.detach().numpy(), ys_mesh.detach().numpy())
ax.scatter(x_obs_i[:n_obs_init,0], x_obs_i[:n_obs_init,1], marker='o', s=40, color='m', label='init. observations')
ax.scatter(x_obs_i[n_obs_init:,0], x_obs_i[n_obs_init:,1], marker='o', s=40, color='cyan', label='BAX acquisitions')


ax.axvline(x_stars[0], ymax=0.1, c='orange', label='sample min emit')
for x_star in x_stars[1:]:
    ax.axvline(x_star, ymax=0.1, c='orange')

ax.axvline(X_tuning_star_i.flatten(), c='r', label='mean min emit')

ax.set_title('GP Posterior Mean - Beamsize')
ax.set_ylabel('$x_2$')
ax.set_xlabel('$x_1$')
ax.legend(loc='upper right')

# %% [markdown]
# # Perform a grid scan of the sample emittances along the single tuning parameter

# %%
X_tuning_scan = torch.linspace(*domain[0],100)
X_tuning_scan = X_tuning_scan.reshape(-1,1)
emits = post_emit(acq_fn_i.algo.post_paths, X_tuning_scan, acq_fn_i.algo.X_meas, samplewise=False, squared=True)

mean_emit = post_mean_emit(acq_fn_i.model, X_tuning_scan, acq_fn_i.algo.X_meas, squared=True)
x_pred, y_pred = acq_fn_i.algo.mean_output(acq_fn_i.model, num_restarts=8)


#compute ground truth emittance for comparison
true_emits_sq = (toy_emit_nd(X_tuning_scan)*1.e6)**2

# %% [markdown]
# # Plot the sample emittance grid scans along with the samplewise optimization results

# %%
emit_stars = post_emit(acq_fn_i.algo.post_paths, torch.tensor(x_stars), acq_fn_i.algo.X_meas, samplewise=True, squared=True)


p = plt.plot(X_tuning_scan.flatten(), true_emits_sq, c='k', linewidth = 4, label='Ground Truth', zorder=28)
    
p = plt.plot(X_tuning_scan.flatten(), mean_emit.detach().numpy(), c='r', linewidth = 4, linestyle=':', label='post. mean', zorder=29)
plt.scatter(x_pred.flatten(), y_pred.flatten().detach(), c='r', s=80, zorder=30)


p = plt.plot(X_tuning_scan.flatten(), emits[0].detach().numpy(), label='post. sample')
x_star = x_stars[0]
emit_star = emit_stars[0]
plt.scatter([x_star[0]],[emit_star.detach().numpy()], c=p[-1].get_color(), label='scipy min')

for i in range(1, n_samples):
    p = plt.plot(X_tuning_scan.flatten(), emits[i].detach().numpy())
    x_star = x_stars[i]
    emit_star = emit_stars[i]
    plt.scatter([x_star[0]],[emit_star.detach().numpy()], c=p[-1].get_color())



plt.title('Pathwise Sample $\epsilon^2$ Optimization - 2d')
plt.xlabel('$x_1$')
plt.ylabel('$\epsilon^{2}$', fontsize=14)
plt.legend()

# %% [markdown]
# # Plot posterior sample beamsize results heatmap (2d)

# %%
#Select sample:
sid = 0 #sample index


fig, ax = plt.subplots(1)

nsteps_mesh = 100
xs_mesh_n_by_d, x_mesh_tuple = build_mesh_domain(nsteps_mesh, domain)
x0mesh, x1mesh = x_mesh_tuple
ys_mesh = acq_fn_i.algo.post_paths(xs_mesh_n_by_d).reshape(acq_fn_i.algo.n_samples,nsteps_mesh,nsteps_mesh)
ax.pcolor(x0mesh.detach().numpy(), x1mesh.detach().numpy(), ys_mesh[sid].detach().numpy())
# ax.scatter(*xs_star[sid], marker='x', s=120, color='r', label='scipy min')


ax.axvline(x_stars[sid], c='orange', label='sample min emit')

ax.set_title('GP Pathwise Posterior Sample - Beamsize')
ax.set_ylabel('$x_2$')
ax.set_xlabel('$x_1$')
ax.legend(loc='upper right')

textstr = 'sample ' + str(sid)


# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', horizontalalignment = 'left', bbox=props)
# Out:
# Text(0.05, 0.95, 'sample 0')

# %%
model_0 = iter_data[0]['model']
x_preds, y_preds = algo.mean_output(model_0)
for j in range(n_iter+1):
    model_j = iter_data[j]['model']
    x_pred_j, y_pred_j = algo.mean_output(model_j)
    x_preds = torch.cat((x_preds, x_pred_j), dim=0)
    y_preds = torch.cat((y_preds, y_pred_j), dim=0)
    
    

true_x_star = torch.tensor([[0.]*(ndim-1)])
true_emit_star = toy_emit_nd(true_x_star)*1.e6

fig, axs = plt.subplots(2, sharex=True)

ax = axs[0]

ax.set_title('Convergence Results')

ax.plot(x_preds.flatten(), label='predicted value')
ax.axhline(0, c='k', linestyle=':', label='ground truth value')

ax.set_ylabel('$\overrightarrow{x^{*}} $')
ax.legend()




ax = axs[1]
ax.plot(torch.clamp(y_preds.detach().flatten(), min=0), label='predicted value')
ax.set_ylabel('$\epsilon^{*2}$')
ax.set_xlabel('iteration')
ax.axhline(true_emit_star**2, c='k', linestyle=':', label='ground truth value')

ax.plot((toy_emit_nd(x_preds)*1.e6)**2)
ax.legend()


plt.tight_layout()
