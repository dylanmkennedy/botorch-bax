# %% [markdown]
# # To-Do:
#
# - InputStandardize vs Normalize
#
# - check hyperparam/prior definitions (scaled space vs raw space)
#
# - keep in mind modality of NaN results in emittance
#
# - Try different number of steps along measurement dimension
#
# - inrease dimensionality of tuning space
#
# - fix legend location (only plot on 1 heatmap)

# %% [markdown]
# # In this notebook, we fit a gpytorch GP to a simple emittance model with 1 tuning parameter. We use the GP to evaluate the Expected Information Gain toward the result of a grid-scan minimization routine.

# %%
import torch
from emitutils import toy_beam_size_squared_nd, fit_gp_model_emittance
from utils import unif_random_sample_domain
from matplotlib import pyplot as plt
from algorithms import GridMinimizeEmittance
from acquisition import ExpectedInformationGain
from botorch.optim import optimize_acqf
import time
from mpl_toolkits.axes_grid1 import make_axes_locatable
import copy

# %% [markdown]
# # Suppress warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CUDA option

# %%
use_gpu = True
if use_gpu:
    if torch.cuda.is_available():
        print('CUDA is available. Using default GPU.')
        torch.set_default_tensor_type('torch.cuda.DoubleTensor')
    else:
        print('CUDA not available. Using CPU.')
        use_gpu = False  
else:
    print('Using CPU.')
# Out:
# CUDA is available. Using default GPU.

# %% [markdown]
# # Monte Carlo Settings

# %%
# domain = torch.tensor([[-2,2], [-65,35]]).double() #the acquisition domain, must have shape = (ndim, 2)
domain = torch.tensor([[-3,1], [-3,1], [-3,1], [-40,60]]).double() #the acquisition domain, must have shape = (ndim, 2)
ndim = domain.shape[0]                               #where domain[i,0] and domain[i,1] represent
                                                        #the lower and upper bounds of the ith input dimension
                                                        #(these same bounds will be applied to the sampled execution paths) 

    

    
n_samples = 10 #number of posterior samples on which to evaluate execution paths
n_steps_tuning_params = 11 #number of steps per dimension in the posterior sample grid scans 
n_steps_measurement_param = 3
squared = True #whether or not to minimize the "emittance squared" (which can be negative according to the model)





random_acq = False
n_trials = 1
n_iter = 50
n_obs_init = 5 #number of random observations on which to initialize model

# %% [markdown]
# # Run trials

# %%
trial_data = {}
trial_data['settings'] = {'domain':domain,
                         'ndim':ndim,
                         'n_obs_init': n_obs_init,
                         'n_samples':n_samples,
                         'n_steps_tuning_params':n_steps_tuning_params,
                         'n_steps_measurement_param': n_steps_measurement_param,
                         'n_trials':n_trials,
                         'n_iter':n_iter,
                         'squared':squared,
                         'random_acq':random_acq}

for trial in range(n_trials):
    torch.manual_seed(trial)

    #build ndim dimensional parabolic target function
    target_func = toy_beam_size_squared_nd


    ##########################################
    #Observe target function n_obs_init times using a uniform sample of the domain
    x_obs = unif_random_sample_domain(n_samples = n_obs_init, domain = domain)

    y_obs = target_func(x_obs)\




    #fit model on initial observations
    model = fit_gp_model_emittance(x_obs, y_obs*1.e6)

    
    algo = GridMinimizeEmittance(domain = domain, 
                   n_samples = n_samples, 
                   n_steps_tuning_params = n_steps_tuning_params,
                    n_steps_measurement_param = n_steps_measurement_param,
                    squared = squared)
    
    rng_state = torch.get_rng_state()
    
    acq_fn = ExpectedInformationGain(model = model, algo = algo)
        
    if random_acq:
        x_next = None
    else:
        x_next, _ = optimize_acqf(
            acq_function=acq_fn,
            bounds=acq_fn.algo.domain.T,
            q=1,
            num_restarts=20,
            raw_samples=100,
            options={},
            )

    
    iter_data = {}
    iter_data[0] = {'x_obs': x_obs,
                   'y_obs': y_obs,
                    'x_next': x_next,
                   'model':  copy.deepcopy(model),
                   'rng_state': rng_state}
    
    times = []
    for i in range(1, n_iter+1):
        start = time.time()
        print('Iteration', trial*n_iter + i, '/', n_trials*n_iter)
        
        if random_acq:
            x_new = unif_random_sample_domain(n_samples = 1, domain = domain)
        else:
            x_new = x_next
            
        y_new = target_func(x_new)

        x_obs = torch.cat((x_obs, x_new), dim=0)
        y_obs = torch.cat((y_obs, y_new), dim=0)

        model = fit_gp_model_emittance(x_obs, y_obs*1.e6)

        rng_state = torch.get_rng_state()
        
        acq_fn = ExpectedInformationGain(model = model, algo = algo)

        
        if random_acq:
            x_next = None
        else:
            x_next, _ = optimize_acqf(
                acq_function=acq_fn,
                bounds=acq_fn.algo.domain.T,
                q=1,
                num_restarts=20,
                raw_samples=100,
                options={},
                )
            
        end = time.time()
        
        this_time = end - start
        
        print('Operation took', this_time, 'seconds.')
        
        times += [this_time]
        
        total_time = sum(times)
        print('Total time elapsed:', total_time, 'seconds.')
        
        total_iters = (trial*n_iter + i)
        avg_time = total_time/total_iters
        print('Estimated time remaining:', avg_time*(n_trials*n_iter - total_iters), 'seconds.')
        
        print('\n')
        
        iter_data[i] = {'x_obs': x_obs,
                   'y_obs': y_obs,
                    'x_next': x_next,
                   'model':  copy.deepcopy(model),
                   'rng_state': rng_state}
        
    trial_data[trial] = iter_data
# Out:
# Iteration 1 / 50
# Operation took 1.7959492206573486 seconds.
# Total time elapsed: 1.7959492206573486 seconds.
# Estimated time remaining: 88.00151181221008 seconds.
#
#
# Iteration 2 / 50
# Operation took 1.6962201595306396 seconds.
# Total time elapsed: 3.4921693801879883 seconds.
# Estimated time remaining: 83.81206512451172 seconds.
#
#
# Iteration 3 / 50
# Operation took 1.6792535781860352 seconds.
# Total time elapsed: 5.171422958374023 seconds.
# Estimated time remaining: 81.01895968119302 seconds.
#
#
# Iteration 4 / 50
# Operation took 2.734670400619507 seconds.
# Total time elapsed: 7.90609335899353 seconds.
# Estimated time remaining: 90.9200736284256 seconds.
#
#
# Iteration 5 / 50
# Operation took 13.719361543655396 seconds.
# Total time elapsed: 21.625454902648926 seconds.
# Estimated time remaining: 194.6290941238403 seconds.
#
#
# Iteration 6 / 50
# Operation took 7.215186357498169 seconds.
# Total time elapsed: 28.840641260147095 seconds.
# Estimated time remaining: 211.49803590774536 seconds.
#
#
# Iteration 7 / 50
# Operation took 5.887476444244385 seconds.
# Total time elapsed: 34.72811770439148 seconds.
# Estimated time remaining: 213.32986589840482 seconds.
#
#
# Iteration 8 / 50
# Operation took 3.4000606536865234 seconds.
# Total time elapsed: 38.128178358078 seconds.
# Estimated time remaining: 200.17293637990952 seconds.
#
#
# Iteration 9 / 50
# Operation took 3.769366979598999 seconds.
# Total time elapsed: 41.897545337677 seconds.
# Estimated time remaining: 190.86659542719522 seconds.
#
#
# Iteration 10 / 50
# Operation took 4.771238088607788 seconds.
# Total time elapsed: 46.66878342628479 seconds.
# Estimated time remaining: 186.67513370513916 seconds.
#
#
# Iteration 11 / 50
# Operation took 3.5558547973632812 seconds.
# Total time elapsed: 50.22463822364807 seconds.
# Estimated time remaining: 178.06917188384315 seconds.
#
#
# Iteration 12 / 50
# Operation took 4.630491495132446 seconds.
# Total time elapsed: 54.85512971878052 seconds.
# Estimated time remaining: 173.7079107761383 seconds.
#
#
# Iteration 13 / 50
# Operation took 3.344848871231079 seconds.
# Total time elapsed: 58.1999785900116 seconds.
# Estimated time remaining: 165.646092910033 seconds.
#
#
# Iteration 14 / 50
# Operation took 9.336973905563354 seconds.
# Total time elapsed: 67.53695249557495 seconds.
# Estimated time remaining: 173.6664492743356 seconds.
#
#
# Iteration 15 / 50
# Operation took 7.222989082336426 seconds.
# Total time elapsed: 74.75994157791138 seconds.
# Estimated time remaining: 174.4398636817932 seconds.
#
#
# Iteration 16 / 50
# Operation took 7.896921157836914 seconds.
# Total time elapsed: 82.65686273574829 seconds.
# Estimated time remaining: 175.64583331346512 seconds.
#
#
# Iteration 17 / 50
# Operation took 3.398716688156128 seconds.
# Total time elapsed: 86.05557942390442 seconds.
# Estimated time remaining: 167.04906594052034 seconds.
#
#
# Iteration 18 / 50
# Operation took 8.604666948318481 seconds.
# Total time elapsed: 94.6602463722229 seconds.
# Estimated time remaining: 168.28488243950738 seconds.
#
#
# Iteration 19 / 50
# Operation took 21.2510986328125 seconds.
# Total time elapsed: 115.9113450050354 seconds.
# Estimated time remaining: 189.11851027137354 seconds.
#
#
# Iteration 20 / 50
# Operation took 4.057741165161133 seconds.
# Total time elapsed: 119.96908617019653 seconds.
# Estimated time remaining: 179.9536292552948 seconds.
#
#
# Iteration 21 / 50
# Operation took 11.713866472244263 seconds.
# Total time elapsed: 131.6829526424408 seconds.
# Estimated time remaining: 181.84788698241826 seconds.
#
#
# Iteration 22 / 50
# Operation took 11.26111102104187 seconds.
# Total time elapsed: 142.94406366348267 seconds.
# Estimated time remaining: 181.92880829897794 seconds.
#
#
# Iteration 23 / 50
# Operation took 12.018911123275757 seconds.
# Total time elapsed: 154.96297478675842 seconds.
# Estimated time remaining: 181.91305735836858 seconds.
#
#
# Iteration 24 / 50
# Operation took 12.36901593208313 seconds.
# Total time elapsed: 167.33199071884155 seconds.
# Estimated time remaining: 181.27632327874502 seconds.
#
#
# Iteration 25 / 50
# Operation took 9.010038375854492 seconds.
# Total time elapsed: 176.34202909469604 seconds.
# Estimated time remaining: 176.34202909469604 seconds.
#
#
# Iteration 26 / 50
# Operation took 8.397545337677002 seconds.
# Total time elapsed: 184.73957443237305 seconds.
# Estimated time remaining: 170.5288379375751 seconds.
#
#
# Iteration 27 / 50
# Operation took 7.669285297393799 seconds.
# Total time elapsed: 192.40885972976685 seconds.
# Estimated time remaining: 163.90384347350508 seconds.
#
#
# Iteration 28 / 50
# Operation took 9.821725130081177 seconds.
# Total time elapsed: 202.23058485984802 seconds.
# Estimated time remaining: 158.89545953273773 seconds.
#
#
# Iteration 29 / 50
# Operation took 7.293436050415039 seconds.
# Total time elapsed: 209.52402091026306 seconds.
# Estimated time remaining: 151.7242910039836 seconds.
#
#
# Iteration 30 / 50
# Operation took 14.83250904083252 seconds.
# Total time elapsed: 224.35652995109558 seconds.
# Estimated time remaining: 149.57101996739706 seconds.
#
#
# Iteration 31 / 50
# Operation took 5.982773065567017 seconds.
# Total time elapsed: 230.3393030166626 seconds.
# Estimated time remaining: 141.17570184892224 seconds.
#
#
# Iteration 32 / 50
# Operation took 7.2424681186676025 seconds.
# Total time elapsed: 237.5817711353302 seconds.
# Estimated time remaining: 133.63974626362324 seconds.
#
#
# Iteration 33 / 50
# Operation took 6.1259095668792725 seconds.
# Total time elapsed: 243.70768070220947 seconds.
# Estimated time remaining: 125.54638096780488 seconds.
#
#
# Iteration 34 / 50
# Operation took 7.3975913524627686 seconds.
# Total time elapsed: 251.10527205467224 seconds.
# Estimated time remaining: 118.16718684925752 seconds.
#
#
# Iteration 35 / 50
# Operation took 16.356706619262695 seconds.
# Total time elapsed: 267.46197867393494 seconds.
# Estimated time remaining: 114.62656228882926 seconds.
#
#
# Iteration 36 / 50
# Operation took 8.79401183128357 seconds.
# Total time elapsed: 276.2559905052185 seconds.
# Estimated time remaining: 107.43288519647388 seconds.
#
#
# Iteration 37 / 50
# Operation took 8.056695699691772 seconds.
# Total time elapsed: 284.3126862049103 seconds.
# Estimated time remaining: 99.89364650442793 seconds.
#
#
# Iteration 38 / 50
# Operation took 7.591349840164185 seconds.
# Total time elapsed: 291.90403604507446 seconds.
# Estimated time remaining: 92.18022190897088 seconds.
#
#
# Iteration 39 / 50
# Operation took 7.2334911823272705 seconds.
# Total time elapsed: 299.13752722740173 seconds.
# Estimated time remaining: 84.37212306413895 seconds.
#
#
# Iteration 40 / 50
# Operation took 7.145941972732544 seconds.
# Total time elapsed: 306.2834692001343 seconds.
# Estimated time remaining: 76.57086730003357 seconds.
#
#
# Iteration 41 / 50
# Operation took 7.858091831207275 seconds.
# Total time elapsed: 314.14156103134155 seconds.
# Estimated time remaining: 68.95790364102619 seconds.
#
#
# Iteration 42 / 50
# Operation took 8.58240532875061 seconds.
# Total time elapsed: 322.72396636009216 seconds.
# Estimated time remaining: 61.4712316876366 seconds.
#
#
# Iteration 43 / 50
# Operation took 7.419327735900879 seconds.
# Total time elapsed: 330.14329409599304 seconds.
# Estimated time remaining: 53.74425717841747 seconds.
#
#
# Iteration 44 / 50

# %%
# import dill
# with open('MC-Emittance-Phys-Random-2d-Results.pkl', 'wb') as f:
#     dill.dump(trial_data, f)

# %%
# import dill
# with open('MC-Emittance-NonPhys-BAX-2d-Results-test.pkl', 'wb') as f:
#     dill.dump(trial_data, f)
